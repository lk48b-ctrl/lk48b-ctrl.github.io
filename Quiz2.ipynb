# %% [markdown]
# <a href="https://colab.research.google.com/github/lk48b-ctrl/lk48b-ctrl.github.io/blob/main/Quiz2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def is_leap_year(year):
    if (year % 4 == 0 and year % 100 != 0) or (year % 400 == 0):
        return True
    return False
def main():
    try:
        # Get user input
        year_input = input("Enter a year: ").strip()

        # Validate input
        if not year_input.isdigit():
            print("Error (Not a year)")
            return

        year = int(year_input)

        # Check leap year
        if is_leap_year(year):
            print(f"{year} is a leap year.")
        else:
            print(f"{year} is not a leap year.")

    except Exception as e:
        print(f"An error occurred: {e}")


if __name__ == "__main__":
    main()
# Out:
# Enter a year: 2024
# 2024 is a leap year.
