# %% [markdown]
# <a href="https://colab.research.google.com/github/lk48b-ctrl/lk48b-ctrl.github.io/blob/main/Quiz3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
multiples = []

for i in range(1, 100001):
    if i % 2 == 0 and i % 3 == 0 and i % 7 == 0:
        multiples.append(i)

print("Total Numbers:", len(multiples))
print("Specific Numbers:", multiples)
# Out:
# Total Numbers: 2380
# ...
